# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\bilyi\appdata\roaming\python\python39\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\bilyi\appdata\roaming\python\python39\site-packages (from opencv-python) (1.24.3)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as clr

# %%
im = cv2.imread("cat.jpg")
plt.axis("off")
plt.imshow(im)
plt.show()

# %% [markdown]
# ## Декомпозиція по складових RGB-моделі

# %%
im_RGB =cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im_RGB)
plt.show()

# %%
R=im_RGB.copy()
R[:,:,(1,2)] = 0
plt.imshow(R)
plt.show()

# %%
G=im_RGB.copy()
G[:,:,(0,2)] = 0
plt.imshow(G)
plt.show()

# %%
B=im_RGB.copy()
B[:,:,(0,1)] = 0
plt.imshow(B)
plt.show()

# %% [markdown]
# ## Декомпозиція по складових HSV-моделі

# %%
im_HSV = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)
plt.imshow(im_HSV)
plt.show()

# %%
H = im_HSV.copy()
H[:,:,(1,2)] = 255
H_RGB = cv2.cvtColor(H,cv2.COLOR_HSV2RGB)
plt.imshow(H_RGB)
plt.show()

# %%
S = im_HSV.copy()
S[:,:,0] = 179
S[:,:,2] = 255
S_RGB = cv2.cvtColor(S,cv2.COLOR_HSV2RGB)
plt.imshow(S_RGB)
plt.show()

# %%
V = im_HSV.copy()
V[:,:,0] = 179
V[:,:,1] = 0
V_RGB = cv2.cvtColor(V,cv2.COLOR_HSV2RGB)
plt.imshow(V_RGB)
plt.show()

# %% [markdown]
# ## Декомпозиція по складових моделі CIE LAB

# %%
im_LAB = cv2.cvtColor(im, cv2.COLOR_BGR2LAB)
plt.imshow(im_LAB)
plt.show()

# %%
L = im_LAB.copy()
L[:,:,(1,2)] = 0
L_RGB = cv2.cvtColor(L,cv2.COLOR_LAB2RGB)
L_GRAY = cv2.cvtColor(L_RGB,cv2.COLOR_RGB2GRAY)
plt.imshow(L_GRAY, cmap = "gray")
plt.show()

# %%
A = im_LAB.copy()
A[:,:,0] = 127
A[:,:,2] = 0
A_RGB = cv2.cvtColor(A,cv2.COLOR_LAB2RGB)
A_GRAY = cv2.cvtColor(A_RGB,cv2.COLOR_RGB2GRAY)
cmap_A = clr.LinearSegmentedColormap.from_list('custom blue', ['Red', 'Gray', 'Green'], N=255)
plt.imshow(A_GRAY, cmap = cmap_A)
plt.show()

# %%
B = im_LAB.copy()
B[:,:,0] = 127
B[:,:,1] = 0
B_RGB = cv2.cvtColor(B,cv2.COLOR_LAB2RGB)
B_GRAY = cv2.cvtColor(B_RGB,cv2.COLOR_RGB2GRAY)
cmap_B = clr.LinearSegmentedColormap.from_list('custom blue', ['Yellow', 'Gray', 'Blue'], N=255)
plt.imshow(B_GRAY, cmap = cmap_B)
plt.show()
